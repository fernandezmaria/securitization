# %% [markdown]
# ## Pyspark example

# %% [markdown]
# Ejecuta la siguiente celda para recrear en el scaffolder un ejemplo con pyspark.
#
# La siguiente celda moverá los ficheros necesarios de la carpeta examples a las carpetas notebooks, de proyecto y tests del scaffolder. Entre ellos, moverá el entrypoint (engine.ipynb) del ejemplo a la carpeta notebooks.
#
# Después deberás ejecutar el [notebook] (engine.ipynb), incluido la ultima celda (enma.convert). Esta celda tendrá como output:
# * el fichero [app.py](app.py) con el código del notebook. Será necesario mover este fichero a la carpeta de proyecto.
# * el fichero [application.conf](application.conf) con las variables de entorno definidas en la celda "#ENVIRONMENT_VARS_PM" del notebook. Será necesario mover este fichero a la carpeta resources.
#
# En ese momento ya tendrás tu engine listo crear una versión y ejecutar desde sandbox manager. Si es tu primera vez puedes encontrar más información del proceso completo en el siguiente [codelab](https://platform.bbva.com/codelabs/sandbox/Codelabs#/sandbox/Create%20an%20engine%20Scaffolder/Introduction/)

# %%
# !cp -r ../examples/pyspark_contracts/* ../

# %%
# !mv ../resources/application.conf.example ../resources/application.conf

# %%
# !pip install enma31==2.0.2 --user

# %%
import enma

# %%
enma.convert("engine.ipynb",".")

# %%
# !mv app.py ../joysticksecuritizatiotl3swp/app.py && mv application.conf ../resources/application.conf

# %% [markdown]
# ## Dataflow examples

# %% [markdown]
# Ejecuta la siguiente celda para recrear en el scaffolder un ejemplo sencillo usando la funcionalidad [Dataflows](https://platform.bbva.com/sandbox/documentation/1fmtqgEyaLMo9TmQJWjtpPYOMHbeuHft43yoK1YOkXuo/engines/dataflows/what-is-and-how-it-works).

# %%
# !cp -f ../examples/enma_dataflow/notebooks/enma_dataflow_basics.ipynb .
# !cp -f ../examples/enma_dataflow/requirements.txt ../requirements.txt

# %% [markdown]
# Ejecuta la siguiente celda para recrear en el scaffolder un ejemplo un poco más completo usando la funcionalidad [Dataflows](https://platform.bbva.com/sandbox/documentation/1fmtqgEyaLMo9TmQJWjtpPYOMHbeuHft43yoK1YOkXuo/engines/dataflows/what-is-and-how-it-works).

# %%
# !cp -f ../examples/enma_dataflow/notebooks/dataflow.ipynb .
# !cp -f ../examples/enma_dataflow/requirements.txt ../requirements.txt

# %% [markdown]
# Si es tu primera vez usando Dataflows, en el siguiente [codelab](https://platform.bbva.com/codelabs/sandbox/Codelabs#/sandbox/Create%20an%20Engine%20Scaffolder%20from%20Dataflow/Introduction/) encontraras un ejemplo práctico de uso.
